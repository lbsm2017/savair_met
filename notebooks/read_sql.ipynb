# %% [markdown]
# # Read SQL Data

# %%
import psycopg2
from psycopg2 import sql
from dotenv import load_dotenv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# Load environment variables from the .secrets file
load_dotenv(".secrets")
# Out:
# True

# %% [markdown]
# ## Initialize SQL connection

# %%
# Database connection parameters from environment variables
DB_NAME = os.getenv("AWS_RDS_DBNAME")
USER = os.getenv("AWS_RDS_USERNAME")
PASSWORD = os.getenv("AWS_RDS_PASSWORD")
HOST = os.getenv("AWS_RDS_HOST")
PORT = os.getenv("AWS_RDS_PORT")

# Connect to PostgreSQL database
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)
cur = conn.cursor()
conn
# Out:
# <connection object at 0x000001EB730EF230; dsn: 'user=lbassetti password=xxx dbname=postgres host=sa-met-1.cna4g6g06njt.eu-central-2.rds.amazonaws.com port=5432', closed: 0>

# %% [markdown]
# ## Read data

# %%
# Query the data
query = """
    SELECT *
    FROM dbt_lbassetti.base_pe_returns 
"""


data = pd.read_sql(query, conn)

# Close the connection
# conn.close()
data
# Out:
# C:\Users\Lorenzo\AppData\Local\Temp\ipykernel_17752\1813841347.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn)
#      vintage_year                        asset_class geo_region  \
# 0            1996             Buyout & Growth Equity       APAC
# 1            1998             Buyout & Growth Equity       APAC
# 2            1999             Buyout & Growth Equity       APAC
# 3            2000             Buyout & Growth Equity       APAC
# 4            2001             Buyout & Growth Equity       APAC
# ..            ...                                ...        ...
# 327          2023                    Venture Capital         US
# 328          2023             Buyout & Growth Equity         US
# 329          2023  Subordinated Capital & Distressed         US
# 330          2023                        Real Estate         US
# 331          2023    Fund of Funds & Secondary Funds         US
#
#     first_transaction_period  as_of_date  fund_count  irr_pooled  \
# 0                    1996 Q1  2024-03-31         8.0    0.048338
# 1                    1998 Q1  2024-03-31        10.0    0.018771
# 2                    1999 Q1  2024-03-31         9.0    0.099353
# 3                    2000 Q1  2024-03-31         8.0    0.195697
# 4                    2001 Q2  2024-03-31         9.0    0.196524
# ..                       ...         ...         ...         ...
# 327                  2023 Q1  2024-03-31        55.0    0.030862
# 328                  2023 Q1  2024-03-31        41.0    0.145259
# 329                  2023 Q1  2024-03-31        11.0    0.239877
# 330                  2023 Q1  2024-03-31        11.0   -0.148758
# 331                  2023 Q1  2024-03-31        11.0    0.675979
#
#      irr_equal_weighted  irr_capital_weighted  irr_average  ...  tvpi_std_dev  \
# 0              0.004460              0.025856    -0.024306  ...      0.613760
# 1              0.026780              0.013794     0.036238  ...      0.506711
# 2              0.130679              0.109944     0.167163  ...      1.300974
# 3              0.159198              0.195583     0.165773  ...      1.159237
# 4              0.186182              0.196417     0.170202  ...      1.063339
# ..                  ...                   ...          ...  ...           ...
# 327           -0.057749             -0.033280    -0.131058  ...      0.177129
# 328           -0.016260              0.124777    -0.027422  ...      0.412742
# 329            0.253213              1.601510     0.129261  ...      0.399433
# 330            0.034740             -0.193510    -0.125276  ...      0.284615
# 331            0.496926              0.613859     0.555816  ...      0.745239
#
#      dpi_pooled  dpi_capital_weighted  dpi_average  dpi_top_5  \
# 0      1.317590              1.256511     1.016255   1.853589
# 1      1.086388              1.080748     1.129784   1.709503
# 2      1.718189              1.746681     1.976349   3.984427
# 3      2.347237              2.439875     1.926944   3.700119
# 4      2.392492              2.276125     2.065716   3.747900
# ..          ...                   ...          ...        ...
# 327    0.000031              0.000042     0.000103   0.000000
# 328    0.012678              0.012375     0.020406   0.058155
# 329    0.018359              0.019396     0.021911   0.073954
# 330    0.005047              0.010614     0.011331   0.062319
# 331    0.015945              0.013054     0.001637   0.009003
#
#      dpi_upper_quartile  dpi_median  dpi_lower_quartile  dpi_bottom_5  \
# 0              1.483729    0.844490            0.655950      0.288713
# 1              1.614811    1.075143            0.771166      0.449256
# 2              2.830999    1.544177            1.126494      0.728574
# 3              2.146291    1.738425            1.457282      0.668606
# 4              2.283240    1.955181            1.433690      0.880326
# ..                  ...         ...                 ...           ...
# 327            0.000000    0.000000            0.000000      0.000000
# 328            0.000000    0.000000            0.000000      0.000000
# 329            0.036922    0.005760            0.000000      0.000000
# 330            0.000000    0.000000            0.000000      0.000000
# 331            0.000000    0.000000            0.000000      0.000000
#
#      dpi_std_dev
# 0       0.613760
# 1       0.506711
# 2       1.302451
# 3       1.190044
# 4       1.063492
# ..           ...
# 327     0.000763
# 328     0.079192
# 329     0.032536
# 330     0.029831
# 331     0.005429
#
# [332 rows x 34 columns]
